# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %%
arr = np.array([1,3,5,7,9])
mean = arr.mean()
std = arr.std()
vfunc = np.vectorize(lambda x: (x - mean) / std) 
new_arr = vfunc(arr) 

mean = 0
std = 1
variance = np.square(std)
x = np.arange(-5,5,0.1)
f = np.exp(-np.square(x - mean)/ 2 * variance)/(np.sqrt(2 * np.pi * variance))

plt.plot(x,f)
plt.show()

# %%
mu = [2, 3]
cov = [[1, 0], [0, 1]]
rv = sp.stats.multivariate_normal(mu, cov)
xx = np.linspace(0, 4, 120)
yy = np.linspace(1, 5, 150)
XX, YY = np.meshgrid(xx, yy)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(XX, YY, rv.pdf(np.dstack((XX, YY))))
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6504\1363834785.py:3: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
